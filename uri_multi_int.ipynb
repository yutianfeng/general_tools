# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import glob

# %% [markdown]
# Preprocess hmmer out with tab script

# %%
hwa = pd.read_table('hwa.htab', sep='\t', lineterminator='\n', skiprows=0)
hwa
# Out:
#        target_name accession  tlen query_name accession.1  qlen  \
# 0   WP_014557079.1         -  2216        msa           -   471
# 1   WP_014557079.1         -  2216        msa           -   471
# 2   WP_014557079.1         -  2216        msa           -   471
# 3   WP_014557079.1         -  2216        msa           -   471
# 4   WP_014557079.1         -  2216        msa           -   471
# 5   WP_014557079.1         -  2216        msa           -   471
# 6   WP_014556498.1         -  1909        msa           -   471
# 7   WP_014556498.1         -  1909        msa           -   471
# 8   WP_049891620.1         -  2142        msa           -   471
# 9   WP_049891620.1         -  2142        msa           -   471
# 10  WP_049891620.1         -  2142        msa           -   471
# 11  WP_049891620.1         -  2142        msa           -   471
# 12  WP_049891620.1         -  2142        msa           -   471
# 13  WP_049891620.1         -  2142        msa           -   471
# 14  WP_014557016.1         -  2289        msa           -   471
# 15  WP_014557016.1         -  2289        msa           -   471
# 16  WP_014556313.1         -   849        msa           -   471
# 17  WP_014556313.1         -   849        msa           -   471
# 18  WP_014556972.1         -   637        msa           -   471
# 19  WP_014556972.1         -   637        msa           -   471
# 20  WP_014556314.1         -  1304        msa           -   471
# 21  WP_014557087.1         -   649        msa           -   471
# 22  WP_014557087.1         -   649        msa           -   471
#
#     full_sequence_E-value  full_sequence_score  full_sequence_bias  dom#  \
# 0           1.300000e-159                529.6                54.6     1
# 1           1.300000e-159                529.6                54.6     2
# 2           1.300000e-159                529.6                54.6     3
# 3           1.300000e-159                529.6                54.6     4
# 4           1.300000e-159                529.6                54.6     5
# 5           1.300000e-159                529.6                54.6     6
# 6           5.000000e-107                356.2                27.6     1
# 7           5.000000e-107                356.2                27.6     2
# 8           3.100000e-104                347.0                24.5     1
# 9           3.100000e-104                347.0                24.5     2
# 10          3.100000e-104                347.0                24.5     3
# 11          3.100000e-104                347.0                24.5     4
# 12          3.100000e-104                347.0                24.5     5
# 13          3.100000e-104                347.0                24.5     6
# 14           4.800000e-80                267.2                17.7     1
# 15           4.800000e-80                267.2                17.7     2
# 16           6.600000e-32                108.5                11.5     1
# 17           6.600000e-32                108.5                11.5     2
# 18           7.100000e-31                105.1                 6.4     1
# 19           7.100000e-31                105.1                 6.4     2
# 20           8.400000e-24                 81.8                 5.6     1
# 21           2.900000e-22                 76.7                 2.3     1
# 22           2.900000e-22                 76.7                 2.3     2
#
#                           ...                          score  bias  \
# 0                         ...                           84.9   5.2
# 1                         ...                           27.2   1.8
# 2                         ...                          135.4   6.0
# 3                         ...                           77.8   0.5
# 4                         ...                           45.2   2.2
# 5                         ...                          185.1   4.7
# 6                         ...                          133.5   5.0
# 7                         ...                          220.6  14.6
# 8                         ...                           30.9   0.3
# 9                         ...                           23.1   0.3
# 10                        ...                          167.8   1.8
# 11                        ...                           16.5   0.1
# 12                        ...                           94.7   0.0
# 13                        ...                           26.8   1.0
# 14                        ...                          150.8   6.9
# 15                        ...                          121.3   2.9
# 16                        ...                           68.5   1.6
# 17                        ...                           42.7   6.0
# 18                        ...                           67.4   0.9
# 19                        ...                           40.2   0.4
# 20                        ...                           81.8   5.6
# 21                        ...                           47.2   0.0
# 22                        ...                           28.4   0.4
#
#     hmm _oord_from  hmm_coord_to  ali_coord_from  ali_coord_to  \
# 0                1           121             336           455
# 1              432           471             506           545
# 2                1           471             572          1093
# 3                1           117            1132          1253
# 4              400           471            1268          1343
# 5                1           471            1357          1929
# 6               19           471             220           610
# 7                1           471            1037          1475
# 8               29           164             328           460
# 9              283           471             573           753
# 10               1           350            1032          1344
# 11             442           471            1359          1390
# 12               1           349            1438          1826
# 13             439           471            1836          1869
# 14               1           467             967          1492
# 15              16           471            1544          2069
# 16               1           161             434           578
# 17             415           471             589           646
# 18               2           119              89           214
# 19             421           471             247           302
# 20              16           470             135           608
# 21               1           148              62           204
# 22             322           471             245           385
#
#     env_coord_from  env_coord_to   acc  \
# 0              336           504  0.87
# 1              477           545  0.91
# 2              572          1093  0.81
# 3             1132          1263  0.92
# 4             1256          1343  0.83
# 5             1357          1929  0.85
# 6              183           610  0.79
# 7             1037          1475  0.92
# 8              319           507  0.70
# 9              568           753  0.70
# 10            1032          1355  0.90
# 11            1343          1390  0.88
# 12            1438          1830  0.77
# 13            1833          1869  0.95
# 14             967          1496  0.78
# 15            1527          2069  0.68
# 16             434           595  0.83
# 17             573           646  0.86
# 18              88           224  0.93
# 19             213           302  0.76
# 20             119           609  0.70
# 21              62           231  0.80
# 22             237           385  0.66
#
#                                 description_of_target
# 0   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 1   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 2   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 3   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 4   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 5   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 6   intein-containing_adenosylcobalamin-dependent_...
# 7   intein-containing_adenosylcobalamin-dependent_...
# 8              DNA_polymerase_[Haloquadratum_walsbyi]
# 9              DNA_polymerase_[Haloquadratum_walsbyi]
# 10             DNA_polymerase_[Haloquadratum_walsbyi]
# 11             DNA_polymerase_[Haloquadratum_walsbyi]
# 12             DNA_polymerase_[Haloquadratum_walsbyi]
# 13             DNA_polymerase_[Haloquadratum_walsbyi]
# 14  DNA_polymerase_II_large_subunit_[Haloquadratum...
# 15  DNA_polymerase_II_large_subunit_[Haloquadratum...
# 16  intein-containing_DNA_gyrase_subunit_B_[Haloqu...
# 17  intein-containing_DNA_gyrase_subunit_B_[Haloqu...
# 18  DNA-directed_RNA_polymerase_subunit_A''_[Haloq...
# 19  DNA-directed_RNA_polymerase_subunit_A''_[Haloq...
# 20       hypothetical_protein_[Haloquadratum_walsbyi]
# 21  replication_factor_C_small_subunit_[Haloquadra...
# 22  replication_factor_C_small_subunit_[Haloquadra...
#
# [23 rows x 23 columns]

# %%
#get all n-terms, need to script _ instead of space and also get rid of #
for indy,row in hwa.iterrows():
    if row['hmm _oord_from'] > 25:
        hwa.drop(index=indy, inplace=True)
hwa
# Out:
#        target_name accession  tlen query_name accession.1  qlen  \
# 0   WP_014557079.1         -  2216        msa           -   471
# 2   WP_014557079.1         -  2216        msa           -   471
# 3   WP_014557079.1         -  2216        msa           -   471
# 5   WP_014557079.1         -  2216        msa           -   471
# 6   WP_014556498.1         -  1909        msa           -   471
# 7   WP_014556498.1         -  1909        msa           -   471
# 10  WP_049891620.1         -  2142        msa           -   471
# 12  WP_049891620.1         -  2142        msa           -   471
# 14  WP_014557016.1         -  2289        msa           -   471
# 15  WP_014557016.1         -  2289        msa           -   471
# 16  WP_014556313.1         -   849        msa           -   471
# 18  WP_014556972.1         -   637        msa           -   471
# 20  WP_014556314.1         -  1304        msa           -   471
# 21  WP_014557087.1         -   649        msa           -   471
#
#     full_sequence_E-value  full_sequence_score  full_sequence_bias  dom#  \
# 0           1.300000e-159                529.6                54.6     1
# 2           1.300000e-159                529.6                54.6     3
# 3           1.300000e-159                529.6                54.6     4
# 5           1.300000e-159                529.6                54.6     6
# 6           5.000000e-107                356.2                27.6     1
# 7           5.000000e-107                356.2                27.6     2
# 10          3.100000e-104                347.0                24.5     3
# 12          3.100000e-104                347.0                24.5     5
# 14           4.800000e-80                267.2                17.7     1
# 15           4.800000e-80                267.2                17.7     2
# 16           6.600000e-32                108.5                11.5     1
# 18           7.100000e-31                105.1                 6.4     1
# 20           8.400000e-24                 81.8                 5.6     1
# 21           2.900000e-22                 76.7                 2.3     1
#
#                           ...                          score  bias  \
# 0                         ...                           84.9   5.2
# 2                         ...                          135.4   6.0
# 3                         ...                           77.8   0.5
# 5                         ...                          185.1   4.7
# 6                         ...                          133.5   5.0
# 7                         ...                          220.6  14.6
# 10                        ...                          167.8   1.8
# 12                        ...                           94.7   0.0
# 14                        ...                          150.8   6.9
# 15                        ...                          121.3   2.9
# 16                        ...                           68.5   1.6
# 18                        ...                           67.4   0.9
# 20                        ...                           81.8   5.6
# 21                        ...                           47.2   0.0
#
#     hmm _oord_from  hmm_coord_to  ali_coord_from  ali_coord_to  \
# 0                1           121             336           455
# 2                1           471             572          1093
# 3                1           117            1132          1253
# 5                1           471            1357          1929
# 6               19           471             220           610
# 7                1           471            1037          1475
# 10               1           350            1032          1344
# 12               1           349            1438          1826
# 14               1           467             967          1492
# 15              16           471            1544          2069
# 16               1           161             434           578
# 18               2           119              89           214
# 20              16           470             135           608
# 21               1           148              62           204
#
#     env_coord_from  env_coord_to   acc  \
# 0              336           504  0.87
# 2              572          1093  0.81
# 3             1132          1263  0.92
# 5             1357          1929  0.85
# 6              183           610  0.79
# 7             1037          1475  0.92
# 10            1032          1355  0.90
# 12            1438          1830  0.77
# 14             967          1496  0.78
# 15            1527          2069  0.68
# 16             434           595  0.83
# 18              88           224  0.93
# 20             119           609  0.70
# 21              62           231  0.80
#
#                                 description_of_target
# 0   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 2   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 3   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 5   ATP-dependent_DNA_helicase_[Haloquadratum_wals...
# 6   intein-containing_adenosylcobalamin-dependent_...
# 7   intein-containing_adenosylcobalamin-dependent_...
# 10             DNA_polymerase_[Haloquadratum_walsbyi]
# 12             DNA_polymerase_[Haloquadratum_walsbyi]
# 14  DNA_polymerase_II_large_subunit_[Haloquadratum...
# 15  DNA_polymerase_II_large_subunit_[Haloquadratum...
# 16  intein-containing_DNA_gyrase_subunit_B_[Haloqu...
# 18  DNA-directed_RNA_polymerase_subunit_A''_[Haloq...
# 20       hypothetical_protein_[Haloquadratum_walsbyi]
# 21  replication_factor_C_small_subunit_[Haloquadra...
#
# [14 rows x 23 columns]

# %%
group = hwa.groupby('target_name')
df2 = group.apply(lambda x: x['ali_coord_from'].unique())
df2
# Out:
# target_name
# WP_014556313.1                     [434]
# WP_014556314.1                     [135]
# WP_014556498.1               [220, 1037]
# WP_014556972.1                      [89]
# WP_014557016.1               [967, 1544]
# WP_014557079.1    [336, 572, 1132, 1357]
# WP_014557087.1                      [62]
# WP_049891620.1              [1032, 1438]
# dtype: object

# %%
HEN = pd.read_csv("hwa_protein.blocked", sep='\t',lineterminator='\n', header=None)
HEN.columns = ['gene', 'motif', 'coord']
hen_groups = HEN.groupby('gene')
df3 = hen_groups.apply(lambda x: x['coord'].unique())
intein_doms = {}
for gene,c_list in df3.iteritems():
    c_list.sort()
    c_index =0 
    c_iter = 1
    while c_index < len(c_list):
        if c_iter < len(c_list):
            if c_list[c_iter] < (c_list[c_index] + 471):
                c_list = np.delete(c_list, c_iter)
                
        c_index += 1
        c_iter += 1
    intein_doms[gene] = (c_list)
intein_doms
# Out:
# {'WP_011570657.1': array([23]),
#  'WP_014555653.1': array([75]),
#  'WP_014555851.1': array([831]),
#  'WP_014555880.1': array([323]),
#  'WP_014555904.1': array([55]),
#  'WP_014556235.1': array([52]),
#  'WP_014556492.1': array([46]),
#  'WP_014556498.1': array([1179]),
#  'WP_014556571.1': array([229]),
#  'WP_014556627.1': array([193]),
#  'WP_014556640.1': array([89]),
#  'WP_014556708.1': array([170]),
#  'WP_014556951.1': array([74]),
#  'WP_014557016.1': array([1349]),
#  'WP_014557079.1': array([893]),
#  'WP_014557087.1': array([245]),
#  'WP_014557105.1': array([547]),
#  'WP_014557117.1': array([277]),
#  'WP_049891620.1': array([ 603, 1230])}

# %%
HEN = pd.read_csv("hwa_protein.blocked", sep='\t',lineterminator='\n', header=None)
HEN.columns = ['gene', 'motif', 'coord']
hen_groups = HEN.groupby('gene')
df3 = hen_groups.apply(lambda x: x['coord'].unique())
intein_doms = {}
for gene,c_list in df3.iteritems():
    c_list.sort()
    c_index =0 
    c_iter = 1
    empty = []
    while c_index < len(c_list):
        if c_iter < len(c_list):
            if c_list[c_iter] < (c_list[c_index] + 471):
                c_list = np.delete(c_list, c_iter)
                c_index -= 1
                c_iter -= 1
        c_index += 1
        c_iter += 1
    intein_doms[gene] = (c_list)
intein_doms
# Out:
# {'WP_011570657.1': array([23]),
#  'WP_014555653.1': array([75]),
#  'WP_014555851.1': array([831]),
#  'WP_014555880.1': array([323]),
#  'WP_014555904.1': array([55]),
#  'WP_014556235.1': array([52]),
#  'WP_014556492.1': array([46]),
#  'WP_014556498.1': array([1179]),
#  'WP_014556571.1': array([229]),
#  'WP_014556627.1': array([193]),
#  'WP_014556640.1': array([89]),
#  'WP_014556708.1': array([170]),
#  'WP_014556951.1': array([74]),
#  'WP_014557016.1': array([1349]),
#  'WP_014557079.1': array([893]),
#  'WP_014557087.1': array([245]),
#  'WP_014557105.1': array([547]),
#  'WP_014557117.1': array([277]),
#  'WP_049891620.1': array([ 603, 1230])}

# %%
for f in intein_doms:
    print(len(intein_doms[f]))
# Out:
# 3
# 1
# 1
# 1
# 1
# 3
# 2
# 1
# 1
# 1
# 1

# %%
multi_inteins = 0
multi_hens = 0
for f,j in df2.iteritems():
    if len(j) > 1:
        multi_inteins += 1
        if f in HEN.values:
            multi_hens += 1

# %%
multi_hens
# Out:
# 4

# %%
multi_inteins 
import os

# %%
for fas in glob.glob("*.htab"):
    genome_name = fas[:13]
    df2 = genome_name + "2"
    
    genome_name = pd.read_table(fas, sep='\t', lineterminator='\n', skiprows=0)
    for indy,row in genome_name.iterrows():
        if row['hmm _oord_from'] > 25:
            genome_name.drop(index=indy, inplace=True)
    
    group = genome_name.groupby('target_name')
    df2 = group.apply(lambda x: x['ali_coord_from'].unique())
    #print(fas[:-5] + "_protein.blocked")
    if os.stat(fas[:-5] + "_protein.blocked").st_size != 0:
        HEN = pd.read_csv(fas[:-5] + "_protein.blocked", sep='\t',lineterminator='\n', header=None)
        HEN.columns = ['gene', 'motif', 'coord']
        hen_groups = HEN.groupby('gene')
        df3 = hen_groups.apply(lambda x: x['coord'].unique())
        intein_doms = {}
        for gene,c_list in df3.iteritems():
            c_list.sort()
            c_index =0 
            c_iter = 1
            while c_index < len(c_list):
                if c_iter < len(c_list):
                    if c_list[c_iter] < (c_list[c_index] + 471):
                        c_list = np.delete(c_list, c_iter)
                        c_index -= 1
                        c_iter -= 1
                c_index += 1
                c_iter += 1
            intein_doms[gene] = (c_list)

    multi_hens = 0
    multi_inteins = 0
    single = 0
    single_hen =0
    multiple = 0
    multiple_hen = 0
    for f,j in df2.iteritems():
        
        if len(j) > 1:
            multiple = multiple + len(j)
            multi_inteins += 1
            if f in HEN.values:
                multi_hens += 1
            if f in intein_doms.keys():
                
                multiple_hen = multiple_hen + len(intein_doms[f])
        if len(j) == 1:
            single += 1
            if f in HEN.values:
                single_hen += 1
    print(fas+ "\t" + str(multi_inteins) + "\t" + str(multi_hens) + "\t" + str(single) + "\t" + str(single_hen) + "\t" + str(multiple) + "\t" + str(multiple_hen), file=open("newcutoffs.tab",'a'))

# %%
genomekey = pd.read_csv("ftpdirpaths.txt", sep='\t',lineterminator='\n', header=None)
genomekey.columns = ['name', 'accession']
replacer = {}
for index,row in genomekey.iterrows():
    replacer[row['accession']] = row['name']
replacer
# Out:
# {'GCF_000762265.1_ASM76226v1': 'Methanobacterium formicicum ',
#  'GCF_001458655.1_Mb9': 'Methanobacterium formicicum ',
#  'GCF_000016525.1_ASM1652v1': 'Methanobrevibacter smithii ATCC 35061 ',
#  'GCF_002813085.1_ASM281308v1': 'Methanobrevibacter smithii ',
#  'GCF_000025865.1_ASM2586v1': 'Methanohalophilus mahii DSM 5219 ',
#  'GCF_001889405.1_ASM188940v1': 'Methanohalophilus halophilus ',
#  'GCF_000166095.1_ASM16609v1': 'Methanothermus fervidus DSM 2088 ',
#  'GCF_000017165.1_ASM1716v1': 'Methanococcus vannielii SB ',
#  'GCF_000006175.1_ASM617v2': 'Methanococcus voltae A3 ',
#  'GCF_000214415.1_ASM21441v1': 'Methanotorris igneus Kol 5 ',
#  'GCF_000091665.1_ASM9166v1': 'Methanocaldococcus jannaschii DSM 2661 ',
#  'GCF_000015825.1_ASM1582v1': 'Methanoculleus marisnigri JR1 ',
#  'GCF_000013445.1_ASM1344v1': 'Methanospirillum hungatei JF-1 ',
#  'GCF_000195895.1_ASM19589v1': 'Methanosarcina barkeri str. Fusaro ',
#  'GCF_000969985.1_ASM96998v1': 'Methanosarcina barkeri str. Wiesmoor ',
#  'GCF_000970025.1_ASM97002v1': 'Methanosarcina barkeri MS ',
#  'GCF_000970065.1_ASM97006v1': 'Methanosarcina barkeri 227 ',
#  'GCF_000970305.1_ASM97030v1': 'Methanosarcina barkeri 3 ',
#  'GCF_001027005.1_ASM102700v1': 'Methanosarcina barkeri CM1 ',
#  'GCF_000007065.1_ASM706v1': 'Methanosarcina mazei Go1 ',
#  'GCF_000970165.1_ASM97016v1': 'Methanosarcina mazei WWM610 ',
#  'GCF_000970185.1_ASM97018v1': 'Methanosarcina mazei SarPi ',
#  'GCF_000970205.1_ASM97020v1': 'Methanosarcina mazei S-6 ',
#  'GCF_000970225.1_ASM97022v1': 'Methanosarcina mazei LYC ',
#  'GCF_000970245.1_ASM97024v1': 'Methanosarcina mazei C16 ',
#  'GCF_000969885.1_ASM96988v1': 'Methanosarcina thermophila TM-1 ',
#  'GCF_000969925.1_ASM96992v1': 'Methanosarcina thermophila CHTI-55 ',
#  'GCF_000969905.1_ASM96990v1': 'Methanosarcina vacuolata Z-761 ',
#  'GCF_000204415.1_ASM20441v1': 'Methanothrix soehngenii GP6 ',
#  'GCF_000970325.1_ASM97032v1': 'Methanococcoides methylutens MM1 ',
#  'GCF_000008665.1_ASM866v1': 'Archaeoglobus fulgidus DSM 4304 ',
#  'GCF_000734035.1_ASM73403v1': 'Archaeoglobus fulgidus DSM 8774 ',
#  'GCF_000011085.1_ASM1108v1': 'Haloarcula marismortui ATCC 43049 ',
#  'GCF_005310945.1_ASM531094v1': 'Haloarcula marismortui ATCC 43049 ',
#  'GCF_000006805.1_ASM680v1': 'Halobacterium salinarum NRC-1 ',
#  'GCF_000069025.1_ASM6902v1': 'Halobacterium salinarum R1 ',
#  'GCF_004799605.1_ASM479960v1': 'Halobacterium salinarum ',
#  'GCF_000025685.1_ASM2568v1': 'Haloferax volcanii DS2 ',
#  'GCF_000022205.1_ASM2220v1': 'Halorubrum lacusprofundi ATCC 49239 ',
#  'GCF_000306765.2_ASM30676v2': 'Haloferax mediterranei ATCC 33500 ',
#  'GCF_005406325.1_ASM540632v1': 'Haloferax mediterranei ATCC 33500 ',
#  'GCF_000026045.1_ASM2604v1': 'Natronomonas pharaonis DSM 2160 ',
#  'GCF_000007305.1_ASM730v1': 'Pyrococcus furiosus DSM 3638 ',
#  'GCF_000275605.1_ASM27560v1': 'Pyrococcus furiosus COM1 ',
#  'GCF_008245085.1_ASM824508v1': 'Pyrococcus furiosus DSM 3638 ',
#  'GCF_002214365.1_ASM221436v1': 'Thermococcus celer Vu 13 = JCM 8558 ',
#  'GCF_000246985.2_ASM24698v3': 'Thermococcus litoralis DSM 5473 ',
#  'GCF_000015225.1_ASM1522v1': 'Thermofilum pendens Hrk 5 ',
#  'GCF_000253055.1_ASM25305v1': 'Thermoproteus tenax Kra 1 ',
#  'GCF_000186365.1_ASM18636v1': 'Desulfurococcus mucosus DSM 2162 ',
#  'GCF_000015205.1_ASM1520v1': 'Pyrobaculum islandicum DSM 4184 ',
#  'GCF_000015945.1_ASM1594v1': 'Staphylothermus marinus F1 ',
#  'GCF_009729015.1_ASM972901v1': 'Acidianus ambivalens ',
#  'GCF_000012285.1_ASM1228v1': 'Sulfolobus acidocaldarius DSM 639 ',
#  'GCF_000338775.1_ASM33877v1': 'Sulfolobus acidocaldarius Ron12/I ',
#  'GCF_000340315.1_ASM34031v1': 'Sulfolobus acidocaldarius N8 ',
#  'GCF_002215405.1_ASM221540v1': 'Sulfolobus acidocaldarius ',
#  'GCF_002215445.1_ASM221544v1': 'Sulfolobus acidocaldarius ',
#  'GCF_002215485.1_ASM221548v1': 'Sulfolobus acidocaldarius ',
#  'GCF_002215525.1_ASM221552v1': 'Sulfolobus acidocaldarius ',
#  'GCF_002215565.1_ASM221556v1': 'Sulfolobus acidocaldarius ',
#  'GCF_000007005.1_ASM700v1': 'Saccharolobus solfataricus P2 ',
#  'GCF_000024745.1_ASM2474v1': 'Saccharolobus solfataricus 98/2 ',
#  'GCF_000968355.1_ASM96835v1': 'Saccharolobus solfataricus ',
#  'GCF_000968395.1_ASM96839v1': 'Saccharolobus solfataricus ',
#  'GCF_000968435.1_ASM96843v1': 'Saccharolobus solfataricus ',
#  'GCF_003852095.1_ASM385209v1': 'Saccharolobus solfataricus ',
#  'GCF_003852135.1_ASM385213v1': 'Saccharolobus solfataricus ',
#  'GCF_003852155.1_ASM385215v1': 'Saccharolobus solfataricus ',
#  'GCF_003852175.1_ASM385217v1': 'Saccharolobus solfataricus ',
#  'GCF_003852195.1_ASM385219v1': 'Saccharolobus solfataricus ',
#  'GCF_003852215.1_ASM385221v1': 'Saccharolobus solfataricus ',
#  'GCF_900079115.1_SSOP1': 'Saccharolobus solfataricus ',
#  'GCF_000195915.1_ASM19591v1': 'Thermoplasma acidophilum DSM 1728 ',
#  'GCF_000012545.1_ASM1254v1': 'Methanosphaera stadtmanae DSM 3091 ',
#  'GCF_902384015.1_UHGG_MGYG-HGUT-02164': 'Methanosphaera stadtmanae ',
#  'GCF_000007185.1_ASM718v1': 'Methanopyrus kandleri AV19 ',
#  'GCF_000196655.1_ASM19665v1': 'Methanohalobium evestigatum Z-7303 ',
#  'GCF_000025625.1_ASM2562v1': 'Natrialba magadii ATCC 43099 ',
#  'GCF_000007225.1_ASM722v1': 'Pyrobaculum aerophilum str. IM2 ',
#  'GCF_002355655.1_ASM235565v1': 'Halorubrum trapanicum ',
#  'GCF_000328685.1_ASM32868v1': 'Natronococcus occultus SP4 ',
#  'GCF_000013725.1_ASM1372v1': 'Methanococcoides burtonii DSM 6242 ',
#  'GCF_000195935.2_ASM19593v1': 'Pyrococcus abyssi GE5 ',
#  'GCF_001190965.1_ASM119096v1': 'Haloferax gibbonsii ',
#  'GCF_000970085.1_ASM97008v1': 'Methanosarcina siciliae T4/M ',
#  'GCF_000970125.1_ASM97012v1': 'Methanosarcina siciliae HI350 ',
#  'GCF_000970145.1_ASM97014v1': 'Methanosarcina siciliae C2J ',
#  'GCF_000011585.1_ASM1158v1': 'Methanococcus maripaludis S2 ',
#  'GCF_000016125.1_ASM1612v1': 'Methanococcus maripaludis C5 ',
#  'GCF_000017225.1_ASM1722v1': 'Methanococcus maripaludis C7 ',
#  'GCF_000018485.1_ASM1848v1': 'Methanococcus maripaludis C6 ',
#  'GCF_000220645.1_ASM22064v1': 'Methanococcus maripaludis X1 ',
#  'GCF_000828535.1_ASM82853v1': 'Methanococcus maripaludis KA1 ',
#  'GCF_000828555.1_ASM82855v1': 'Methanococcus maripaludis OS7 ',
#  'GCF_002945325.1_ASM294532v1': 'Methanococcus maripaludis ',
#  'GCF_003052125.1_ASM305212v1': 'Methanococcus maripaludis ',
#  'GCF_000217995.1_ASM21799v1': 'Methanosalsum zhilinae DSM 4017 ',
#  'GCF_003201835.1_ASM320183v1': 'Acidianus brierleyi ',
#  'GCF_009729035.1_ASM972903v1': 'Stygiolobus azoricus ',
#  'GCF_000017185.1_ASM1718v1': 'Methanococcus aeolicus Nankai-3 ',
#  'GCF_000022385.1_ASM2238v1': 'Sulfolobus islandicus L.S.2.15 ',
#  'GCF_000022405.1_ASM2240v1': 'Sulfolobus islandicus M.14.25 ',
#  'GCF_000022425.1_ASM2242v1': 'Sulfolobus islandicus M.16.27 ',
#  'GCF_000022445.1_ASM2244v1': 'Sulfolobus islandicus M.16.4 ',
#  'GCF_000022465.1_ASM2246v1': 'Sulfolobus islandicus Y.G.57.14 ',
#  'GCF_000022485.1_ASM2248v1': 'Sulfolobus islandicus Y.N.15.51 ',
#  'GCF_000189555.1_ASM18955v1': 'Sulfolobus islandicus REY15A ',
#  'GCF_000364745.1_ASM36474v1': 'Sulfolobus islandicus LAL14/1 ',
#  'GCF_000016605.1_ASM1660v1': 'Metallosphaera sedula DSM 5348 ',
#  'GCF_001266655.1_ASM126665v1': 'Metallosphaera sedula ',
#  'GCF_001266675.1_ASM126667v1': 'Metallosphaera sedula ',
#  'GCF_001266695.1_ASM126669v1': 'Metallosphaera sedula ',
#  'GCF_001266715.1_ASM126671v1': 'Metallosphaera sedula ',
#  'GCF_001266735.1_ASM126673v1': 'Metallosphaera sedula ',
#  'GCF_000230715.2_ASM23071v3': 'Natronobacterium gregoryi SP2 ',
#  'GCF_002214585.1_ASM221458v1': 'Thermococcus profundus ',
#  'GCF_000011185.1_ASM1118v1': 'Thermoplasma volcanium GSS1 ',
#  'GCF_000223905.1_ASM22390v1': 'Haloarcula hispanica ATCC 33960 ',
#  'GCF_000504565.1_ASM50456v2': 'Haloarcula hispanica N601 ',
#  'GCF_001592435.1_ASM159243v1': 'Thermococcus peptonophilus ',
#  'GCF_000011105.1_ASM1110v1': 'Pyrococcus horikoshii OT3 ',
#  'GCF_002214465.1_ASM221446v1': 'Thermococcus barossii ',
#  'GCF_000147875.1_ASM14787v1': 'Methanolacinia petrolearia DSM 11571 ',
#  'GCF_000015145.1_ASM1514v1': 'Hyperthermus butylicus DSM 5456 ',
#  'GCF_000223395.1_ASM22339v1': 'Pyrolobus fumarii 1A ',
#  'GCF_000092185.1_ASM9218v1': 'Thermosphaera aggregans DSM 11486 ',
#  'GCF_001481685.1_ASM148168v1': 'Ignicoccus islandicus DSM 13165 ',
#  'GCF_000025505.1_ASM2550v1': 'Ferroglobus placidus DSM 10642 ',
#  'GCF_002214605.1_ASM221460v1': 'Thermococcus chitonophagus ',
#  'GCF_900012635.1_Pyrococcus_chitonophagus_genome_sequence': 'Thermococcus chitonophagus ',
#  'GCF_000151105.2_ASM15110v2': 'Thermococcus barophilus MP ',
#  'GCF_001433455.1_ASM143345v1': 'Thermococcus barophilus ',
#  'GCF_000011125.1_ASM1112v1': 'Aeropyrum pernix K1 ',
#  'GCF_000023965.1_ASM2396v1': 'Halomicrobium mukohataei DSM 12286 ',
#  'GCF_004803735.1_ASM480373v1': 'Halomicrobium mukohataei ',
#  'GCF_009217585.1_ASM921758v1': 'Halomicrobium mukohataei ',
#  'GCF_000194625.1_ASM19462v1': 'Archaeoglobus veneficus SNP6 ',
#  'GCF_002813655.1_ASM281365v1': 'Methanobacterium subterraneum ',
#  'GCF_002813695.1_ASM281369v1': 'Methanobacterium subterraneum ',
#  'GCF_000172995.2_ASM17299v2': 'Halogeometricum borinquense DSM 11551 ',
#  'GCF_004799645.1_ASM479964v1': 'Natronorubrum bangense ',
#  'GCF_000025325.1_ASM2532v1': 'Haloterrigena turkmenica DSM 5511 ',
#  'GCF_000092305.1_ASM9230v1': 'Methanocaldococcus infernus ME ',
#  'GCF_000230735.2_ASM23073v3': 'Natrinema pellirubrum DSM 15624 ',
#  'GCF_005890195.1_ASM589019v1': 'Natrinema pallidum ',
#  'GCF_009729055.1_ASM972905v1': 'Sulfurisphaera ohwakuensis ',
#  'GCF_000019805.1_ASM1980v1': 'Pyrobaculum neutrophilum V24Sta ',
#  'GCF_002214385.1_ASM221438v1': 'Thermococcus gorgonarius ',
#  'GCF_002214485.1_ASM221448v1': 'Thermococcus pacificus ',
#  'GCF_002214505.1_ASM221450v1': 'Thermococcus siculi ',
#  'GCF_000024625.1_ASM2462v1': 'Methanocaldococcus vulcanius M7 ',
#  'GCF_002078355.1_ASM207835v1': 'Ferroplasma acidiphilum ',
#  'GCF_000018305.1_ASM1830v1': 'Caldivirga maquilingensis IC-167 ',
#  'GCF_003201675.1_ASM320167v1': 'Metallosphaera hakonensis JCM 8857 = DSM 7519 ',
#  'GCF_000008265.1_ASM826v1': 'Picrophilus torridus DSM 9790 ',
#  'GCF_000023985.1_ASM2398v1': 'Methanocaldococcus fervens AG86 ',
#  'GCF_000024185.1_ASM2418v1': 'Methanobrevibacter ruminantium M1 ',
#  'GCF_000015765.1_ASM1576v1': 'Methanocorpusculum labreanum Z ',
#  'GCF_000304355.2_Mb_MS2': 'Methanoculleus bourgensis MS2 ',
#  'GCF_000025285.1_ASM2528v1': 'Archaeoglobus profundus DSM 5631 ',
#  'GCF_000092465.1_ASM9246v1': 'Staphylothermus hellenicus DSM 12710 ',
#  'GCF_900036045.1_Methanoculleus_sp_MAB1': 'Methanoculleus sp. MAB1 ',
#  'GCF_005576615.1_ASM557661v1': 'Natrinema versiforme ',
#  'GCF_000020905.1_ASM2090v1': 'Desulfurococcus amylolyticus 1221n ',
#  'GCF_000231015.2_ASM23101v3': 'Desulfurococcus amylolyticus DSM 16532 ',
#  'GCF_000152265.2_ASM15226v2': 'Ferroplasma acidarmanus fer1 ',
#  'GCF_000328665.1_ASM32866v1': 'Methanomethylovorans hollandica DSM 15978 ',
#  'GCF_000816105.1_ASM81610v1': 'Thermococcus guaymasensis DSM 11113 ',
#  'GCF_000011205.1_ASM1120v1': 'Sulfurisphaera tokodaii str. 7 ',
#  'GCF_001006045.1_ASM100604v1': 'Geoglobus ahangari ',
#  'GCF_900095295.1_MCBB': 'Methanobacterium congolense ',
#  'GCF_000016385.1_ASM1638v1': 'Pyrobaculum arsenaticum DSM 13514 ',
#  'GCF_002214525.1_ASM221452v1': 'Thermococcus sp. P6 ',
#  'GCF_900095815.1_SIV6': 'Methanothermobacter wolfeii ',
#  'GCF_000008645.1_ASM864v1': 'Methanothermobacter thermautotrophicus str. Delta H ',
#  'GCF_000145295.1_ASM14529v1': 'Methanothermobacter marburgensis str. Marburg ',
#  'GCF_000023945.1_ASM2394v1': 'Halorhabdus utahensis DSM 12940 ',
#  'GCF_000179575.2_ASM17957v2': 'Methanothermococcus okinawensis IH1 ',
#  'GCF_000017945.1_ASM1794v1': 'Ignicoccus hospitalis KIN4/I ',
#  'GCF_000265525.1_ASM26552v1': 'Thermococcus cleftensis ',
#  'GCF_000148385.1_ASM14838v1': 'Vulcanisaeta distributa DSM 14429 ',
#  'GCF_000970265.1_ASM97026v1': 'Methanosarcina lacustris Z-7289 ',
#  'GCF_000022545.1_ASM2254v1': 'Thermococcus sibiricus MM 739 ',
#  'GCF_000193375.1_ASM19337v1': 'Thermoproteus uzoniensis 768-20 ',
#  'GCF_000022365.1_ASM2236v1': 'Thermococcus gammatolerans EJ3 ',
#  'GCF_002214565.1_ASM221456v1': 'Thermococcus radiotolerans ',
#  'GCF_000585495.1_ASM58549v1': 'Thermococcus nautili ',
#  'GCF_000317795.1_ASM31779v1': 'Caldisphaera lagunensis DSM 15908 ',
#  'GCF_000404165.1_ASM40416v1': 'Methanobrevibacter sp. AbM4 ',
#  'GCF_000226975.2_ASM22697v3': 'Halobiforma lacisalsi AJ5 ',
#  'GCF_000591035.1_ASM59103v1': 'Aeropyrum camini SY1 = JCM 12091 ',
#  'GCF_001477655.1_ASM147765v1': 'Methanobrevibacter millerae ',
#  'GCF_000144915.1_ASM14491v1': 'Acidilobus saccharovorans 345-15 ',
#  'GCF_000151205.2_ASM15120v2': 'Thermococcus sp. AM4 ',
#  'GCF_002214545.1_ASM221454v1': 'Thermococcus thioreducens ',
#  'GCF_002116695.1_ASM211669v1': 'Acidianus manzaensis ',
#  'GCF_000009185.1_ASM918v1': 'Haloquadratum walsbyi DSM 16790 ',
#  'GCF_000237865.1_ASM23786v1': 'Haloquadratum walsbyi C23 ',
#  'GCF_001563245.1_ASM156324v1': 'Methanobrevibacter olleyae ',
#  'GCF_000235565.1_ASM23556v1': 'Methanosaeta harundinacea 6Ac ',
#  'GCF_000009965.1_ASM996v1': 'Thermococcus kodakarensis KOD1 ',
#  'GCF_003201765.1_ASM320176v1': 'Acidianus sulfidivorans JP7 ',
#  'GCF_004126515.1_ASM412651v1': 'Halorubrum ezzemoulense ',
#  'GCF_000018465.1_ASM1846v1': 'Nitrosopumilus maritimus SCM1 ',
#  'GCF_000018365.1_ASM1836v1': 'Thermococcus onnurineus NA1 ',
#  'GCF_000211475.1_ASM21147v1': 'Pyrococcus sp. NA2 ',
#  'GCF_009392895.1_ASM939289v1': 'Natronorubrum aibiense ',
#  'GCF_000517625.1_ASM51762v1': 'Halostagnicola larsenii XH-48 ',
#  'GCF_000017625.1_ASM1762v1': 'Methanoregula boonei 6A8 ',
#  'GCF_000025665.1_ASM2566v1': 'Aciduliprofundum boonei T469 ',
#  'GCF_000328525.1_ASM32852v1': 'Halovivax ruber XH-70 ',
#  'GCF_000217715.1_ASM21771v1': 'Halopiger xanaduensis SH-6 ',
#  'GCF_000281695.1_ASM28169v1': 'Natrinema sp. J7-2 ',
#  'GCF_000196895.1_ASM19689v1': 'Halalkalicoccus jeotgali B3 ',
#  'GCF_000591055.1_ASM59105v1': 'Natronomonas moolapensis 8.8.11 ',
#  'GCF_000970285.1_ASM97028v1': 'Methanosarcina horonobensis HB-1 = JCM 15518 ',
#  'GCF_000470655.1_HATI1': 'Halorhabdus tiamatea SARL4B ',
#  'GCF_000021965.1_ASM2196v1': 'Methanosphaerula palustris E1-9c ',
#  'GCF_000303155.1_ASM30315v1': 'Candidatus Nitrososphaera gargensis Ga9.2 ',
#  'GCF_000019605.1_ASM1960v1': 'Candidatus Korarchaeum cryptofilum OPF8 ',
#  'GCF_000213215.1_ASM21321v1': 'Acidianus hospitalis W1 ',
#  'GCF_000789255.1_ASM78925v1': 'Geoglobus acetivorans ',
#  'GCF_000011005.1_ASM1100v1': 'Methanocella paludicola SANAE ',
#  'GCF_000517445.1_ASM51744v1': 'Thermococcus paralvinellae ',
#  'GCF_001971705.1_ASM197170v1': 'Haloterrigena daqingensis ',
#  'GCF_003990725.1_ASM399072v1': 'Halorubrum sp. PV6 ',
#  'GCF_000025525.1_ASM2552v1': 'Methanocaldococcus sp. FS406-22 ',
#  'GCF_003856835.1_ASM385683v1': 'Haloplanus aerogenes ',
#  'GCF_000327505.1_ASM32750v1': 'Aciduliprofundum sp. MAR08-339 ',
#  'GCF_000258425.1_ASM25842v1': 'Fervidicoccus fontis Kam940 ',
#  'GCF_004799685.1_ASM479968v1': 'Halobellus limi ',
#  'GCF_002156705.1_ASM215670v1': 'Natronolimnobius aegyptiacus ',
#  'GCF_000230955.2_ASM23095v3': 'Halobacterium sp. DL1 ',
#  'GCF_002906575.1_ASM290657v1': 'Salinigranum rubrum ',
#  'GCF_000224475.1_ASM22447v1': 'halophilic archaeon DL31 ',
#  'GCF_000828575.1_ASM82857v1': 'Methanothermobacter sp. CaT2 ',
#  'GCF_000214725.1_ASM21472v1': 'Methanobacterium paludis ',
#  'GCF_000191585.1_ASM19158v1': 'Methanobacterium lacus ',
#  'GCF_000327485.1_ASM32748v1': 'Methanoregula formicica SMSP ',
#  'GCF_000725425.1_ASM72542v1': 'Palaeococcus pacificus DY20341 ',
#  'GCF_000190315.1_ASM19031v1': 'Vulcanisaeta moutnovskia 768-28 ',
#  'GCF_000204925.1_ASM20492v1': 'Metallosphaera cuprina Ar-4 ',
#  'GCF_000215995.1_ASM21599v1': 'Pyrococcus yayanosii CH1 ',
#  'GCF_000698785.1_ASM69878v1': 'Nitrososphaera viennensis EN76 ',
#  'GCF_000221185.1_ASM22118v1': 'Thermococcus sp. 4557 ',
#  'GCF_002355635.1_ASM235563v1': 'Halopenitus persicus ',
#  'GCF_000350305.1_ASM35030v1': 'Thermoplasmatales archaeon BRNA1 ',
#  'GCF_002788215.1_ASM278821v1': 'Halohasta litchfieldiae ',
#  'GCF_900065925.1_NDEV.embl.gz': 'Candidatus Nitrosotalea devanaterra ',
#  'GCF_000234805.1_ASM23480v1': 'Pyrobaculum ferrireducens ',
#  'GCF_000251105.1_ASM25110v1': 'Methanocella conradii HZ254 ',
#  'GCF_000063445.1_ASM6344v1': 'Methanocella arvoryzae MRE50 ',
#  'GCF_000263735.1_ASM26373v1': 'Pyrococcus sp. ST04 ',
#  'GCF_000264495.1_ASM26449v1': 'Thermogladius calderae 1633 ',
#  'GCF_000299395.1_ASM29939v1': 'Candidatus Nitrosopumilus sediminis ',
#  'GCF_001412615.1_ASM141261v1': 'Pyrodictium delaneyi ',
#  'GCF_000300255.2_ASM30025v2': 'Candidatus Methanomethylophilus alvus Mx1201 ',
#  'GCF_003711245.1_ASM371124v1': 'Candidatus Methanomethylophilus alvus ',
#  'GCF_902387285.1_UHGG_MGYG-HGUT-02456': 'Candidatus Methanomethylophilus alvus ',
#  'GCF_008326425.1_SulIC006_1.0': 'Sulfolobus sp. JCM 16833 ',
#  'GCF_000739065.1_ASM73906v1': 'Methanocaldococcus bathoardescens ',
#  'GCF_000385565.1_ASM38556v1': 'Archaeoglobus sulfaticallidus PM70-1 ',
#  'GCF_000403645.1_ASM40364v1': 'Salinarchaeum sp. Harcht-Bsk1 ',
#  'GCF_000446015.1_ASM44601v1': 'Thermofilum adornatus ',
#  'GCF_000813245.1_ASM81324v1': 'Thermofilum adornatus 1505 ',
#  'GCF_000499765.1_Methanobacterium': 'Methanobacterium sp. MB1 ',
#  'GCF_009690625.1_ASM969062v1': 'Halorhabdus sp. CBA1104 ',
#  'GCF_000404225.1_ASM40422v1': 'Candidatus Methanomassiliicoccus intestinalis Issoire-Mx1 ',
#  'GCF_902383905.1_UHGG_MGYG-HGUT-02160': 'Candidatus Methanomassiliicoccus intestinalis ',
#  'GCF_001488575.1_Halobacterium_hubeiense_JI20-1': 'Halobacterium hubeiense ',
#  'GCF_000812185.1_ASM81218v1': 'Candidatus Nitrosopelagicus brevis ',
#  'GCF_000969945.1_ASM96994v1': 'Methanosarcina sp. Kolksee ',
#  'GCF_000970045.1_ASM97004v1': 'Methanosarcina sp. MTP4 ',
#  'GCF_000970005.1_ASM97000v1': 'Methanosarcina sp. WH1 ',
#  'GCF_000969965.1_ASM96996v1': 'Methanosarcina sp. WWM596 ',
#  'GCF_004799665.1_ASM479966v1': 'Halapricum salinum ',
#  'GCF_000730285.1_ASM73028v1': 'Candidatus Nitrososphaera evergladensis SR1 ',
#  'GCF_001560915.1_ASM156091v1': 'methanogenic archaeon ISO4-H5 ',
#  'GCF_000769655.1_ASM76965v1': 'Thermococcus eurythermalis ',
#  'GCF_000299365.1_ASM29936v1': 'Candidatus Nitrosopumilus koreensis AR1 ',
#  'GCF_003342675.1_ASM334267v1': 'Haloplanus sp. CBA1112 ',
#  'GCF_003342695.1_ASM334269v1': 'Haloplanus sp. CBA1113 ',
#  'GCF_000993805.1_ASM99380v1': 'Thermofilum uzonense ',
#  'GCF_003431325.1_ASM343132v1': 'Acidilobus sp. 7A ',
#  'GCF_000800805.1_ASM80080v1': 'Candidatus Methanoplasma termitum ',
#  'GCF_000956175.1_ASM95617v1': 'Nitrosopumilus adriaticus ',
#  'GCF_000875775.1_ASM87577v1': 'Nitrosopumilus piranensis ',
#  'GCF_000827835.1_ASM82783v1': 'Haloarcula sp. CBA1115 ',
#  'GCF_000955905.1_ASM95590v3': 'Candidatus Nitrosotenuis cloacae ',
#  'GCF_001011115.1_ASM101111v1': 'Halanaeroarchaeum sulfurireducens ',
#  'GCF_001305655.1_ASM130565v1': 'Halanaeroarchaeum sulfurireducens ',
#  'GCF_001577775.1_ASM157777v1': 'Pyrococcus kukulkanii ',
#  'GCF_001548675.1_ASM154867v1': 'Methanobrevibacter sp. YE315 ',
#  'GCF_003967175.1_Sacidi_1.0': 'Sulfodiicoccus acidiphilus ',
#  'GCF_900083515.1_ASM90008351v1': 'Cuniculiplasma divulgatum ',
#  'GCF_900090055.1_C.divulgatum_PM4': 'Cuniculiplasma divulgatum ',
#  'GCF_001484685.1_ASM148468v1': 'Thermococcus sp. 2319x1 ',
#  'GCF_003058365.1_ASM305836v1': 'Haloarculaceae archaeon HArcel1 ',
#  'GCF_001647085.1_ASM164708v1': 'Thermococcus piezophilus ',
#  'GCF_003268005.1_ASM326800v1': 'Methanosphaera sp. BMS ',
#  'GCF_900696045.1_Nitrosocosmicus_franklandus_C13': 'Candidatus Nitrosocosmicus franklandus ',
#  'GCF_001870125.1_ASM187012v1': 'Candidatus Nitrosocosmicus exaquare ',
#  'GCF_002787055.1_ASM278705v1': 'Candidatus Nitrosotenuis aquarius ',
#  'GCF_001767315.1_ASM176731v1': 'Halodesulfurarchaeum formicicum ',
#  'GCF_001886955.1_ASM188695v1': 'Halodesulfurarchaeum formicicum ',
#  'GCF_001719125.1_ASM171912v1': 'Sulfolobus sp. A20 ',
#  'GCF_002156965.1_ASM215696v1': 'Candidatus Nitrosomarinus catalina ',
#  'GCF_002813675.1_ASM281367v1': 'Methanobacterium sp. MZ-A1 ',
#  'GCF_002214165.1_ASM221416v1': 'Candidatus Mancarchaeum acidiphilum ',
#  'GCF_002844335.1_ASM284433v1': 'Haloarcula taiwanensis ',
#  'GCF_001989615.1_ASM198961v1': 'Halorientalis sp. IM1011 ',
#  'GCF_002197185.1_ASM219718v1': 'Thermococcus sp. 5-4 ',
#  'GCF_900198835.1_chr_EXT12c': 'Thermococcus sp. EXT12c ',
#  'GCF_003430805.1_ASM343080v1': 'Natronolimnobius sulfurireducens ',
#  'GCF_003430825.1_ASM343082v1': 'Natronolimnobius sulfurireducens ',
#  'GCF_002906215.1_ASM290621v1': 'Candidatus Nitrosocaldus islandicus ',
#  'GCF_002952775.1_ASM295277v1': 'Halalkaliarchaeum desulfuricum ',
#  'GCF_900248165.1_Nitrosocaldus_cavascurensis_SCU2_chromosome': 'Candidatus Nitrosocaldus cavascurensis ',
#  'GCF_008326385.1_SulIC007_1.0': 'Sulfolobus sp. JCM 16834 ',
#  'GCF_004114375.1_ASM411437v1': 'Halorubrum sp. BOL3-1 ',
#  'GCF_004087835.1_ASM408783v1': 'Halorussus sp. RC-68 ',
#  'GCF_006740685.1_ASM674068v1': 'Candidatus Nitrosopumilus sp. SW ',
#  'GCF_009617975.1_ASM961797v1': 'DPANN group archaeon LC1Nh ',
#  'GCF_005155585.1_ASM515558v1': 'Haloprofundus sp. MHR1 ',
#  'GCF_005954745.1_ASM595474v1': 'Halostella sp. DL-M4 ',
#  'GCF_006274605.1_ASM627460v1': 'Thermococcus sp. IOH1 ',
#  'GCF_008000775.1_ASM800077v1': 'anaerobic archaeon MK-D1 ',
#  'GCF_008152015.1_ASM815201v1': 'Thermococcus sp. SY113 ',
#  'GCF_007833275.1_ASM783327v1': 'Salarchaeum sp. JOR-1 ',
#  'GCF_008033705.1_ASM803370v1': 'Methanothermobacter sp. KEPCO1 ',
#  'GCF_003351865.1_ASM335186v1': 'Methanofervidicoccus sp. A16 ',
#  'GCF_009617995.1_ASM961799v1': 'Halomicrobium sp. LC1Hm ',
#  'GCF_009601705.1_ASM960170v1': 'Sulfolobus sp. E5-1-F ',
#  'GCF_009602405.1_ASM960240v1': 'Sulfolobus sp. E11-6 '}

# %%
archtab2 = pd.read_csv("newcutoffs.tab", sep='\t',lineterminator='\n', header=None)
archtab2.columns = ['name', 1, 2,3, 4, 5, 6]

# %%
for index,row in archtab2.iterrows():
    archtab2.set_value(index, 'name', replacer[row['name']])
archtab2.to_csv('named_newcutoff.csv', sep='\t', index_label=None, line_terminator='\n')
# Out:
# /home/tian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
cd ../full_run1/
# Out:
# /media/tian/Backup_Protected/working/multi_inteins/full_run1
